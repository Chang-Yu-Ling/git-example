div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%95%8F%E9%A1%8C%5D&#43;Pixel5%E7%BA%8C%E8%88%AA%E6%8E%89%E5%BE%88%E5%A4%A7%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BE%A6%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Akywood">搜尋看板內 kywood 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1632715576.A.195.html">[公告] MobileComm板規</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ginlom</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;MobileComm%E6%9D%BF%E8%A6%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Aginlom">搜尋看板內 ginlom 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/27</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">50</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/MobileComm/M.1721266183.A.DEA.html">[置底] 2024下半年閒聊區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">starskyjth</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/MobileComm/search?q=thread%3A%5B%E7%BD%AE%E5%BA%95%5D&#43;2024%E4%B8%8B%E5%8D%8A%E5%B9%B4%E9%96%92%E8%81%8A%E5%8D%80">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/MobileComm/search?q=author%3Astarskyjth">搜尋看板內 starskyjth 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://www.ptt.cc/bbs/MobileComm/index.html") #將網頁資料GET下來
soup = BeautifulSoup(r.text,"html.parser") #將網頁資料以html.parser
sel = soup.select("div.title a") #取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
for s in sel:
    print(s["href"], s.text)
# Out:
# /bbs/MobileComm/M.1731154859.A.364.html [購機] 20K以下 音遊+AR攝影
# /bbs/MobileComm/M.1731156181.A.40D.html [新聞] Google 知道 Tensor 處理器的問題， G6
# /bbs/MobileComm/M.1731156837.A.CB0.html [問題] galaxy watch
# /bbs/MobileComm/M.1731157905.A.5A1.html [討論] 有人還記得黑莓機嗎？
# /bbs/MobileComm/M.1731160107.A.2BA.html Re: [討論] 大家用過最久的手機壽命是多長？
# /bbs/MobileComm/M.1731162154.A.4B0.html [購機] OPPO Reno 12 vs 紅米 Note 13 pro+
# /bbs/MobileComm/M.1731167010.A.5F6.html [心得] 三星綠線維修心得
# /bbs/MobileComm/M.1731170201.A.ACE.html [問題] 請問中華4g.怎麼脫離111.71
# /bbs/MobileComm/M.1731171138.A.523.html Re: [問題] iphone開機密碼忘記只能打掉重來了嗎？
# /bbs/MobileComm/M.1731190949.A.F6D.html Re: [方案] 遠傳 全聯方案
# /bbs/MobileComm/M.1731203583.A.307.html [購機] 10K內 工作用拍照錄影長續航
# /bbs/MobileComm/M.1731203696.A.0E2.html Re: [心得] 三星綠線維修心得
# /bbs/MobileComm/M.1731207613.A.15E.html [問題] 萬元內空機推薦
# /bbs/MobileComm/M.1731211895.A.F63.html [方案] 4G吃到飽方案 <= 399
# /bbs/MobileComm/M.1731213387.A.012.html [問題] Xiaomi Watch 2 Pro如何？
# /bbs/MobileComm/M.1731213658.A.FA3.html [問題] Pixel5續航掉很大該怎麼辦？
# /bbs/MobileComm/M.1632715576.A.195.html [公告] MobileComm板規
# /bbs/MobileComm/M.1721266183.A.DEA.html [置底] 2024下半年閒聊區
